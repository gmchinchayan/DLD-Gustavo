# %%
import pandas as pd
import numpy as np

import nltk
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
data = pd.read_csv('chatgreekgodx091421Clean.csv')
data.head()
# Out:
#                   Date     Channel         Username  \
# 0  2021-09-14 17:51:09  greekgodx         mustfax19
# 1  2021-09-14 17:51:09  greekgodx          bangkeys
# 2  2021-09-14 17:51:09  greekgodx   exiledxinsanity
# 3  2021-09-14 17:51:10  greekgodx            leeqox
# 4  2021-09-14 17:51:10  greekgodx           adamev1
#
#                           Message  Tag_owner        Cleanest_message  \
# 0                          Pepega          0                  pepega
# 1              Irl stream snipers          0       irl stream sniper
# 2             v tec kicked in Pog          0          v tec kick pog
# 3  Alarm turn up the volume Alarm          0  alarm turn volum alarm
# 4                     Pepega Clap          0             pepega clap
#
#   clean_message_duplicates
# 0                   Pepega
# 1       Irl stream snipers
# 2         v tec kicked Pog
# 3        Alarm turn volume
# 4              Pepega Clap

# %%
analyser = SentimentIntensityAnalyzer()

# %%
new_emotes = {
    'omegalul': 2,
    'lilw': 0,
    'monkaw': -3.0,
    'waytoodank': 0,
    'ez': 2.0,
    'clap' : 3.0,
    'lul' : 2.0,
    'booba' : 1.0,
    'pepega' : -3.0,
    'feelsgoodman' : 3.0,
    'wutfac' : -3.0,
    'sadge' : -4.0,
    'kreygasm' : 3.0,
    'kappa' : 0,
    'peeposad' : -4.0,
    'pogu' : 4.0,
    'truening' : 0,
    'lulw' : 2.0,
    'feelsbadman' : -3.0,
    'pogchamp' : 3.0,
    'poggers' : 3.0,
    'heyguys' : 2.0,
    'pepehands': -2.0,
    'rip' : -2.0,
    'seemsgood' : 3.0,
    'notlikethis' : -2.0,
    'clap' : 2.0,
    'pog' : 2.0,
    'smorc' : 0,
    'dansgam' : -4.0,
    'ez' : -1.0,
    'peeposad' : -2.0,
    
    
    
    
}

# %%
analyser.lexicon.update(new_emotes)

# %%
data['scores'] = data['Cleanest_message'].apply(lambda clean_message:analyser.polarity_scores(clean_message))

# %%
data.head(5)
# Out:
#                   Date     Channel         Username  \
# 0  2021-09-14 17:51:09  greekgodx         mustfax19
# 1  2021-09-14 17:51:09  greekgodx          bangkeys
# 2  2021-09-14 17:51:09  greekgodx   exiledxinsanity
# 3  2021-09-14 17:51:10  greekgodx            leeqox
# 4  2021-09-14 17:51:10  greekgodx           adamev1
#
#                           Message  Tag_owner        Cleanest_message  \
# 0                          Pepega          0                  pepega
# 1              Irl stream snipers          0       irl stream sniper
# 2             v tec kicked in Pog          0          v tec kick pog
# 3  Alarm turn up the volume Alarm          0  alarm turn volum alarm
# 4                     Pepega Clap          0             pepega clap
#
#   clean_message_duplicates                                             scores
# 0                   Pepega  {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound...
# 1       Irl stream snipers  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2         v tec kicked Pog  {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound...
# 3        Alarm turn volume  {'neg': 0.706, 'neu': 0.294, 'pos': 0.0, 'comp...
# 4              Pepega Clap  {'neg': 0.571, 'neu': 0.0, 'pos': 0.429, 'comp...

# %%
total=analyser.polarity_scores(data['Cleanest_message'])

# %%
total
# Out:
# {'neg': 0.111, 'neu': 0.659, 'pos': 0.229, 'compound': 1.0}

# %%
pd.set_option('display.max_colwidth', 200)

# %%
data.head()
# Out:
#                   Date     Channel         Username  \
# 0  2021-09-14 17:51:09  greekgodx         mustfax19
# 1  2021-09-14 17:51:09  greekgodx          bangkeys
# 2  2021-09-14 17:51:09  greekgodx   exiledxinsanity
# 3  2021-09-14 17:51:10  greekgodx            leeqox
# 4  2021-09-14 17:51:10  greekgodx           adamev1
#
#                           Message  Tag_owner        Cleanest_message  \
# 0                          Pepega          0                  pepega
# 1              Irl stream snipers          0       irl stream sniper
# 2             v tec kicked in Pog          0          v tec kick pog
# 3  Alarm turn up the volume Alarm          0  alarm turn volum alarm
# 4                     Pepega Clap          0             pepega clap
#
#   clean_message_duplicates  \
# 0                   Pepega
# 1       Irl stream snipers
# 2         v tec kicked Pog
# 3        Alarm turn volume
# 4              Pepega Clap
#
#                                                           scores
# 0      {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.6124}
# 1          {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 2       {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.4588}
# 3  {'neg': 0.706, 'neu': 0.294, 'pos': 0.0, 'compound': -0.5859}
# 4    {'neg': 0.571, 'neu': 0.0, 'pos': 0.429, 'compound': -0.25}

# %%
data['comp_score'] = data['scores'].apply(lambda score_dict: score_dict['compound'])

# %%
data.head()
# Out:
#                   Date     Channel         Username  \
# 0  2021-09-14 17:51:09  greekgodx         mustfax19
# 1  2021-09-14 17:51:09  greekgodx          bangkeys
# 2  2021-09-14 17:51:09  greekgodx   exiledxinsanity
# 3  2021-09-14 17:51:10  greekgodx            leeqox
# 4  2021-09-14 17:51:10  greekgodx           adamev1
#
#                           Message  Tag_owner        Cleanest_message  \
# 0                          Pepega          0                  pepega
# 1              Irl stream snipers          0       irl stream sniper
# 2             v tec kicked in Pog          0          v tec kick pog
# 3  Alarm turn up the volume Alarm          0  alarm turn volum alarm
# 4                     Pepega Clap          0             pepega clap
#
#   clean_message_duplicates  \
# 0                   Pepega
# 1       Irl stream snipers
# 2         v tec kicked Pog
# 3        Alarm turn volume
# 4              Pepega Clap
#
#                                                           scores  comp_score
# 0      {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.6124}     -0.6124
# 1          {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}      0.0000
# 2       {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.4588}      0.4588
# 3  {'neg': 0.706, 'neu': 0.294, 'pos': 0.0, 'compound': -0.5859}     -0.5859
# 4    {'neg': 0.571, 'neu': 0.0, 'pos': 0.429, 'compound': -0.25}     -0.2500

# %%
data['sentiment']=''
data.loc[data.comp_score>0,'sentiment']='POSITIVE'
data.loc[data.comp_score==0,'sentiment']='NEUTRAL'
data.loc[data.comp_score<0,'sentiment']='NEGATIVE'

# %%
data.head()
# Out:
#                   Date     Channel         Username  \
# 0  2021-09-14 17:51:09  greekgodx         mustfax19
# 1  2021-09-14 17:51:09  greekgodx          bangkeys
# 2  2021-09-14 17:51:09  greekgodx   exiledxinsanity
# 3  2021-09-14 17:51:10  greekgodx            leeqox
# 4  2021-09-14 17:51:10  greekgodx           adamev1
#
#                           Message  Tag_owner        Cleanest_message  \
# 0                          Pepega          0                  pepega
# 1              Irl stream snipers          0       irl stream sniper
# 2             v tec kicked in Pog          0          v tec kick pog
# 3  Alarm turn up the volume Alarm          0  alarm turn volum alarm
# 4                     Pepega Clap          0             pepega clap
#
#   clean_message_duplicates  \
# 0                   Pepega
# 1       Irl stream snipers
# 2         v tec kicked Pog
# 3        Alarm turn volume
# 4              Pepega Clap
#
#                                                           scores  comp_score  \
# 0      {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.6124}     -0.6124
# 1          {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}      0.0000
# 2       {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.4588}      0.4588
# 3  {'neg': 0.706, 'neu': 0.294, 'pos': 0.0, 'compound': -0.5859}     -0.5859
# 4    {'neg': 0.571, 'neu': 0.0, 'pos': 0.429, 'compound': -0.25}     -0.2500
#
#   sentiment
# 0  NEGATIVE
# 1   NEUTRAL
# 2  POSITIVE
# 3  NEGATIVE
# 4  NEGATIVE

# %%
data.sentiment.value_counts().plot(kind='bar',title="sentiment analysis")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-23-7d69bebcb961> in <module>
# ----> 1 data.sentiment.value_counts().plot(kind='bar',title="sentiment analysis")
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     890
#     891     def __call__(self, *args, **kwargs):
# --> 892         plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     893
#     894         x, y, kind, kwargs = self._get_call_args(
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\plotting\_core.py in _get_plot_backend(backend)
#    1812         return _backends[backend]
#    1813
# -> 1814     module = _load_backend(backend)
#    1815     _backends[backend] = module
#    1816     return module
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\plotting\_core.py in _load_backend(backend)
#    1752             module = importlib.import_module("pandas.plotting._matplotlib")
#    1753         except ImportError:
# -> 1754             raise ImportError(
#    1755                 "matplotlib is required for plotting when the "
#    1756                 'default backend "matplotlib" is selected.'
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.

# %%
data.to_csv (r'C:\Users\Aleksandra\Desktop\new1_data.csv', index = False, header=True)
