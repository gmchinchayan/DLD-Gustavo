# %% [markdown]
# imported pandas as pd

# %%
import pandas as pd

# %% [markdown]
# used pandas to read from Chatlogs where Average is 10 second

# %%
df = pd.read_csv('C:/Users/Gustavo Chinchayan/Documents/Python/DLD/DS_Files/ChatLogs/chatriotgames/chatriotgames101821Average10Second.csv', index_col='Date', parse_dates=True)

# %% [markdown]
# we print the data with head and tail

# %%
print('Shape of data',df.shape)
df.head(), df.tail()
# Out:
# Shape of data (346, 1)
# (                     comp_score
#  Date
#  2021-10-18 17:18:00    0.652300
#  2021-10-18 17:18:10    0.178052
#  2021-10-18 17:18:20    0.096158
#  2021-10-18 17:18:30    0.114636
#  2021-10-18 17:18:40    0.045829,
#                       comp_score
#  Date
#  2021-10-18 18:14:50   -0.148738
#  2021-10-18 18:15:00   -0.054930
#  2021-10-18 18:15:10   -0.088500
#  2021-10-18 18:15:20   -0.154814
#  2021-10-18 18:15:30   -0.195750)

# %% [markdown]
# we plot the comp score and this is visualization of the plot, as you can see it looks quite noisy

# %%
df['comp_score'].plot(figsize=(12,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### We use Statsmodel library and import adfuller to do the
# #### Augmented Dicker Fuller Test to see if our dataset is Stationary

# %%
from statsmodels.tsa.stattools import adfuller
def adf_test(dataset):
     dftest = adfuller(dataset, autolag = 'AIC')
     print("1. ADF : ",dftest[0])
     print("2. P-Value : ", dftest[1])
     print("3. Num Of Lags : ", dftest[2])
     print("4. Num Of Observations Used For ADF Regression:",      dftest[3])
     print("5. Critical Values :")
     for key, val in dftest[4].items():
         print("\t",key, ": ", val)
        
adf_test(df['comp_score'])
# Out:
# 1. ADF :  -4.460210579709871
# 2. P-Value :  0.00023188669402738653
# 3. Num Of Lags :  9
# 4. Num Of Observations Used For ADF Regression: 336
# 5. Critical Values :
# 	 1% :  -3.449962981927952
# 	 5% :  -2.870180642420163
# 	 10% :  -2.5713734527352607

# %% [markdown]
# As you can see P-value is under 0.05 so we reject Null hypothesis and the dataset is stationary

# %%
import statsmodels.api as sm
from statsmodels.tsa.stattools import acf,pacf
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### We import ACF and PACF tooks from the statsmodel library and matplot converters to plot some crucial graphs

# %%
res = sm.tsa.seasonal_decompose(df, period=60)
resplot = res.plot()
plt.show()

# %% [markdown]
# we do seasonal compose to view the plots and see wether there is any pattern we can see, it

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df, lags=20, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df, lags=20, ax=ax2)

# %% [markdown]
# #### This is the ACF and PACF plot as you can see most lags sit outside the confidence interval region, and each lag correlates in time with each other.

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
plot_acf(df, ax=None, lags=20, alpha=0.05)
plt.show()
plot_pacf(df, ax=None, lags=20, alpha=0.05)
plt.show()

# %% [markdown]
# ### We use pmdarima and import auto_arima library to do a stepwise search to minimize AIC and find the best AIC model for our dataset

# %%
from pmdarima import auto_arima
stepwise_fit = auto_arima(df['comp_score'], trace=True,
suppress_warnings=True)
#because our dataset is stationary and non seasonal
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.37 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-458.246, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-485.310, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-499.930, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-460.110, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-506.440, Time=0.08 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.30 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=-510.604, Time=0.23 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=-520.440, Time=0.33 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=-518.317, Time=0.35 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=-506.605, Time=0.38 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=-508.916, Time=0.27 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=-512.724, Time=0.46 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=-520.726, Time=0.27 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=-512.188, Time=0.07 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=-522.348, Time=0.20 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=-508.136, Time=0.04 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=-519.559, Time=0.10 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=inf, Time=0.32 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=-501.686, Time=0.03 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=-521.713, Time=0.15 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=-520.804, Time=0.31 sec
#
# Best model:  ARIMA(1,1,2)(0,0,0)[0]
# Total fit time: 4.618 seconds

# %% [markdown]
# We split out dataset 80% training and 20% test

# %%
print(df.shape)
train=df.iloc[:-30]
test=df.iloc[-30:]
print(train.shape,test.shape)
# Out:
# (346, 1)
# (316, 1) (30, 1)

# %% [markdown]
# #### We import ARIMA from statsmodel to test the new model, SARIMAX gives a summary of the results

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(df, order=(1,1,2))
model=model.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             comp_score   No. Observations:                  346
# Model:                 ARIMA(1, 1, 2)   Log Likelihood                 265.174
# Date:                Mon, 29 Nov 2021   AIC                           -522.348
# Time:                        02:55:31   BIC                           -506.974
# Sample:                    10-18-2021   HQIC                          -516.225
#                          - 10-18-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7439      0.070     10.614      0.000       0.607       0.881
# ma.L1         -1.2015      0.084    -14.364      0.000      -1.365      -1.038
# ma.L2          0.2156      0.074      2.915      0.004       0.071       0.361
# sigma2         0.0125      0.001     15.383      0.000       0.011       0.014
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.15   Jarque-Bera (JB):                35.23
# Prob(Q):                              0.70   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.72   Skew:                             0.23
# Prob(H) (two-sided):                  0.08   Kurtosis:                         4.50
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# We do an ARIMA model test on our new model

# %%
start=len(train)
end=len(train)+len(test)-1
pred=model.predict(start=start,end=end,typ='levels').rename('ARIMA predictions')
pred.plot(legend=True, figsize=(12,10))
train['comp_score'].plot(legend=True)
plt.axhline(y=0.0, color='r', linestyle='--')

# %% [markdown]
# These are the predictions made by our ARIMA model -in blue known as ARIMA (ML model) predictions and -in orange is the comp_score which is the actual dataset

# %%
pred.plot(legend='ARIMA Predictions')
test['comp_score'].plot(legend=True, figsize=(12,10))
plt.axhline(y=0.0, color='r', linestyle='--')

# %% [markdown]
# These are the predictions made by our ARIMA model -in blue known as ARIMA (ML model) predictions and -in orange is the comp_score which is the actual dataset - this is only on the TEST dataset.

# %%
from sklearn import metrics
from math import sqrt
import numpy as np
test['comp_score'].mean()
print('RMSE', np.sqrt(metrics.mean_squared_error(pred, test['comp_score'])))
print('MAE', metrics.mean_absolute_error(pred, test['comp_score'])*100)
print('MSE', metrics.mean_squared_error(pred, test['comp_score']))
# Out:
# RMSE 0.09344554149692333
# MAE 7.581319886499302
# MSE 0.00873206922565322

# %% [markdown]
# ### We Import metrics RMSE, MAE, and MSE to evaluate performance of the ARIMA model

# %%
test['comp_score'].mean()
# Out:
# -0.08405475946177801

# %% [markdown]
# These are the future Forecast Predictions the ARIMA model makes

# %%
model2=ARIMA(df['comp_score'],order=(1,1,1))
model2=model2.fit()
df.tail()
# Out:
#                      comp_score
# Date
# 2021-10-18 18:14:50   -0.148738
# 2021-10-18 18:15:00   -0.054930
# 2021-10-18 18:15:10   -0.088500
# 2021-10-18 18:15:20   -0.154814
# 2021-10-18 18:15:30   -0.195750

# %% [markdown]
# We import Pandas and Matplotlib to see the residuals and density of the dataset

# %%
from pandas import DataFrame
from matplotlib import pyplot
import matplotlib.pyplot as plt
residuals = pd.DataFrame(model2.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0], figsize=(10,10))
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %%
start2=len(train)
end2=len(train)+12

# %% [markdown]
# We make the ARIMA make Future Forecast Predictions based on the ARIMA model

# %%
pred2 = model2.predict(start=start2,end=end2,typ='levels').rename('ARIMA2 Predictions')
print(pred2)
# Out:
# 2021-10-18 18:14:00    0.034501
# 2021-10-18 18:14:10   -0.012775
# 2021-10-18 18:14:20   -0.103233
# 2021-10-18 18:14:30   -0.182436
# 2021-10-18 18:14:40   -0.188381
# 2021-10-18 18:14:50   -0.013497
# 2021-10-18 18:15:00   -0.100733
# 2021-10-18 18:15:10   -0.044165
# 2021-10-18 18:15:20   -0.065218
# 2021-10-18 18:15:30   -0.106867
# 2021-10-18 18:15:40   -0.133550
# 2021-10-18 18:15:50   -0.096924
# 2021-10-18 18:16:00   -0.075356
# Freq: 10S, Name: ARIMA2 Predictions, dtype: float64

# %% [markdown]
# This Plot is the ARIMA2 Predictions (that is in Blue) including future predictions, as observed the model only makes good short predictions but over time the prediction sentiment scores converge to zero.
#
# The Comp_score is the Actual in the Test Region

# %%
pred2.plot(figsize=(10,8),legend=True)
test['comp_score'].plot(legend=True)
plt.axhline(y=0.0, color='r', linestyle='--')
