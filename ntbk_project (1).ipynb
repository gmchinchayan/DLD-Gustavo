# %%
import twitch
from twitch_chat_analyzer_mod import analyzer
import pdb

# %%
clientHelix = twitch.TwitchHelix(client_id="zcmx2b7yss60bn022uizawju3drozg", client_secret="rirjohlwwvhysysc7pbj9l8acvy0lj", scopes=[twitch.constants.OAUTH_SCOPE_ANALYTICS_READ_EXTENSIONS])

# %%
myOauth = clientHelix.get_oauth()
videoID = ["892647155"]

# %%
userID = clientHelix.get_videos(videoID)[0].user_id
clientHelix.get_videos(videoID)
# Out:
# [{'id': '892647155',
#   'stream_id': '41504260046',
#   'user_id': '124422593',
#   'user_login': 'lec',
#   'user_name': 'LEC',
#   'title': '2021 LEC Spring - Week 2 Day 1',
#   'description': '',
#   'created_at': datetime.datetime(2021, 1, 29, 15, 30, 36),
#   'published_at': datetime.datetime(2021, 1, 29, 15, 30, 36),
#   'url': 'https://www.twitch.tv/videos/892647155',
#   'thumbnail_url': 'https://static-cdn.jtvnw.net/cf_vods/d2nvs31859zcd8/466fc5cca7454b8b9992_lec_41504260046_1611934228//thumb/thumb0-%{width}x%{height}.jpg',
#   'viewable': 'public',
#   'view_count': 1706906,
#   'language': 'en',
#   'type': 'archive',
#   'duration': '6h53m56s',
#   'muted_segments': None}]

# %%
Videos = clientHelix.get_videos(user_id = userID,page_size = 5)

# %%
VideosIDs = []
for i in range(len(Videos)):
    VideosIDs.append(Videos[i].id)

# %%
VideosChat = []

# %%
for i in range(len(VideosIDs)):
    videoChat = analyzer.FromVideoId(VideosIDs[i])
    VideosChat.append(videoChat.ToDataFrame())
breakpoint()
# Out:
# Downloading chat of VOD: 2021 LEC Summer - Finals Warmup by LEC
# Total 170584 chats downloaded. 100.00% complete
# Download complete in 1678 seconds
# Chat saved to  .\chatlogs\lec\1133445014.json
#
# Downloading chat of VOD: 2021 LEC Summer - Semifinals: RGE vs FNC by LEC
# Total 65226 chats downloaded. 100.00% complete
# Download complete in 617 seconds
# Chat saved to  .\chatlogs\lec\1132400929.json
#
# Downloading chat of VOD: 2021 LEC Summer - Playoffs Round 3: G2 vs FNC by LEC
# Total 143528 chats downloaded. 100.00% complete
# Download complete in 1409 seconds
# Chat saved to  .\chatlogs\lec\1126512673.json
#
# Downloading chat of VOD: 2021 LEC Summer - Semifinals: RGE vs MAD by LEC
# Total 64380 chats downloaded. 100.00% complete
# Download complete in 536 seconds
# Chat saved to  .\chatlogs\lec\1125496919.json
#
# Downloading chat of VOD: 2021 LEC Summer - Playoffs Round 2: MSF vs FNC by LEC
# Total 1803 chats downloaded. 12.22% complete
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-f0db624e649b> in <module>
#       1 for i in range(len(VideosIDs)):
# ----> 2     videoChat = analyzer.FromVideoId(VideosIDs[i])
#       3     VideosChat.append(videoChat.ToDataFrame())
#       4 breakpoint()
#
# ~\Downloads\twitch_chat_analyzer_mod\analyzer.py in FromVideoId(video_id)
#     113
#     114   # If not already downloaded, download the chat
# --> 115   data_json = downloader.downloadChat(video_id)
#     116   return ChatAnalyzer(data_json['video'], data_json['comments'])
#     117
#
# ~\.conda\envs\nlp_course\lib\site-packages\twitch_chat_analyzer\downloader.py in downloadChat(video_id, save_to_file)
#      23   comments_generator = client.GetComments(video_id)
#      24   comments = []
# ---> 25   for comments_batch in comments_generator:
#      26     comments.extend(comments_batch)
#      27     comment_count = len(comments)
#
# ~\.conda\envs\nlp_course\lib\site-packages\twitch_chat_analyzer\kraken.py in GetComments(self, video_id)
#      34     while cursor is not None:
#      35       url = BASE_URL % 'videos/' + str(video_id) + '/comments?cursor=' + cursor
# ---> 36       comments_batch = self._GetUrl(url)
#      37       cursor = comments_batch.get('_next')
#      38       yield comments_batch['comments']
#
# ~\.conda\envs\nlp_course\lib\site-packages\twitch_chat_analyzer\kraken.py in _GetUrl(self, url)
#      39
#      40   def _GetUrl(self, url):
# ---> 41     response = self.session.get(url, headers=self.headers)
#      42     if response.status_code >= 400:
#      43       print('Request to', url, 'failed with status code', response.status_code)
#
# ~\.conda\envs\nlp_course\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     553
#     554         kwargs.setdefault('allow_redirects', True)
# --> 555         return self.request('GET', url, **kwargs)
#     556
#     557     def options(self, url, **kwargs):
#
# ~\.conda\envs\nlp_course\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\.conda\envs\nlp_course\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\.conda\envs\nlp_course\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~\.conda\envs\nlp_course\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     704                 body=body,
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#     708
#
# ~\.conda\envs\nlp_course\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\.conda\envs\nlp_course\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\.conda\envs\nlp_course\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~\.conda\envs\nlp_course\lib\http\client.py in getresponse(self)
#    1367         try:
#    1368             try:
# -> 1369                 response.begin()
#    1370             except ConnectionError:
#    1371                 self.close()
#
# ~\.conda\envs\nlp_course\lib\http\client.py in begin(self)
#     308         # read until we get a non-100 response
#     309         while True:
# --> 310             version, status, reason = self._read_status()
#     311             if status != CONTINUE:
#     312                 break
#
# ~\.conda\envs\nlp_course\lib\http\client.py in _read_status(self)
#     269
#     270     def _read_status(self):
# --> 271         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     272         if len(line) > _MAXLINE:
#     273             raise LineTooLong("status line")
#
# ~\.conda\envs\nlp_course\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\.conda\envs\nlp_course\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# ~\.conda\envs\nlp_course\lib\ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
data=VideosChat[0]

# %%
data
# Out:
#         bits                                               body  \
# 0          0                                        MorphinTime
# 1          0                                    HeyGuys HeyGuys
# 2          0                         PogChamp PogChamp PogChamp
# 3          0                                          caedChair
# 4          0                                    HeyGuys HeyGuys
# 5          0                                            HeyGuys
# 6          0                                    HeyGuys HeyGuys
# 7          0                                          SeemsGood
# 8          0            SeemsGood SeemsGood SeemsGood SeemsGood
# 9          0                                            HeyGuys
# 10         0                                        MorphinTime
# 11         0                                           PogChamp
# 12         0                                            HeyGuys
# 13         0                                            WutFace
# 14         0                                    ResidentSleeper
# 15         0                    HeyGuys HeyGuys HeyGuys HeyGuys
# 16         0                                        <3 <3 <3 <3
# 17         0                                          SeemsGood
# 18         0                                            HeyGuys
# 19         0                                          SeemsGood
# 20         0                            VoteYea VoteYea VoteYea
# 21         0                                    HeyGuys HeyGuys
# 22         0                                            WutFace
# 23         0                                          nisqyTeam
# 24         0                                drututDog drututDog
# 25         0                                           <3 <3 <3
# 26         0                                            LUL LUL
# 27         0                                               KEKW
# 28         0                                                 hi
# 29         0                                              First
# ...      ...                                                ...
# 170554     0                                             MaxLOL
# 170555     0                buerinMusic buerinMusic buerinMusic
# 170556     0                                         PokPikachu
# 170557     0                                  <3 <3 <3 <3 <3 <3
# 170558     0                                   <3 BibleThump <3
# 170559     0                               <3 <3 <3 <3 <3 <3 <3
# 170560     0                                        Kappa Kappa
# 170561     0                                          maholi2Xd
# 170562     0                                                 <3
# 170563     0                            PowerUpL DxCat PowerUpR
# 170564     0                PogChamp PogChamp PogChamp PogChamp
# 170565     0                         <3 <3 KappaRoss BloodTrail
# 170566     0                                                 <3
# 170567     0                                                 <3
# 170568     0                                         mave88Love
# 170569     0                                           <3 <3 <3
# 170570     0                              BibleThump BibleThump
# 170571     0                <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3
# 170572     0                NotLikeThis NotLikeThis NotLikeThis
# 170573     0                PogChamp PogChamp PogChamp PogChamp
# 170574     0                                            FortOne
# 170575     0                           BibleThump BibleThump :D
# 170576     0  2020Celebrate 2020Celebrate 2020Celebrate 2020...
# 170577     0  HungryPaimon HungryPaimon HungryPaimon HungryP...
# 170578     0                                          EleGiggle
# 170579     0                                                 :)
# 170580     0                                        larcen2Wave
# 170581     0                                     <3 <3 <3 <3 <3
# 170582     0                                          ahnyfaPog
# 170583     0                         sinaOdin sinaOdin sinaOdin
#
#                      display_name  is_sub_notice  is_subscriber  \
# 0                       238SAMIxD          False          False
# 1                     alexbomba25          False          False
# 2                      Reformance          False          False
# 3                       j0hn_w3st          False          False
# 4                    mohamedmak11          False          False
# 5                          Mossez          False          False
# 6                   TheGameFramer          False          False
# 7                         lemonzw          False          False
# 8                          nomacu          False          False
# 9                         SaschZi          False          False
# 10                     powervital          False          False
# 11                        Gibbxyz          False          False
# 12                      serjjarch          False          False
# 13                  karcsi1111222          False          False
# 14                      son_abdul          False          False
# 15                      Dunforth1          False          False
# 16                  roseecho25345          False          False
# 17                 BangBangityBam          False          False
# 18                       Schwille          False          False
# 19                      yeesharoo          False          False
# 20                       Patatsta          False          False
# 21               autofill_collins          False          False
# 22                       Tamare31          False          False
# 23                      j0hn_w3st          False          False
# 24                     harakaishu          False          False
# 25                       cremuwka          False          False
# 26                        lemonzw          False          False
# 27                    CaniellaFae          False          False
# 28                         oMeIon          False          False
# 29                    darkbunny11          False          False
# ...                           ...            ...            ...
# 170554           MadamPandamonium          False          False
# 170555                asap_cvmpxs          False          False
# 170556                 itsKiksuya          False          False
# 170557                  Smoothyde          False          False
# 170558                hi_im_ayuki          False          False
# 170559                 UstaGevsek          False          False
# 170560  gracwlolamuszebosieudusze          False          False
# 170561                     Echosm          False          False
# 170562                     mmated          False          False
# 170563                    Golonk4          False          False
# 170564                  mstfbglyn          False          False
# 170565           MadamPandamonium          False          False
# 170566                   gege_101          False          False
# 170567                    Sganian          False          False
# 170568                  MartinFNT          False          False
# 170569                     kkbyt9          False          False
# 170570                   shenlagh          False          False
# 170571                   badwaduu          False          False
# 170572                  escoesco_          False          False
# 170573                    Borieko          False          False
# 170574                    HAXUS01          False          False
# 170575           MadamPandamonium          False          False
# 170576                 Yasuoazaki          False          False
# 170577                    bpa1708          False          False
# 170578                  davidpg99          False          False
# 170579                    SKYGA01          False          False
# 170580                 LarcenyCat          False          False
# 170581            theundertaker21          False          False
# 170582              joaoesteves10          False          False
# 170583                 cchasechen          False          False
#
#                              name  offset   text_body  \
# 0                       238SAMIxD       8
# 1                     alexbomba25      27
# 2                      Reformance      27
# 3                       j0hn_w3st      40
# 4                    mohamedmak11      40
# 5                          Mossez      46
# 6                   TheGameFramer      47
# 7                         lemonzw      50
# 8                          nomacu      52
# 9                         SaschZi      53
# 10                     powervital      53
# 11                        Gibbxyz      54
# 12                      serjjarch      57
# 13                  karcsi1111222      58
# 14                      son_abdul      58
# 15                      Dunforth1      63
# 16                  roseecho25345      64
# 17                 BangBangityBam      65
# 18                       Schwille      65
# 19                      yeesharoo      66
# 20                       Patatsta      67
# 21               autofill_collins      67
# 22                       Tamare31      68
# 23                      j0hn_w3st      71
# 24                     harakaishu      73
# 25                       cremuwka      89
# 26                        lemonzw      90
# 27                    CaniellaFae      92        KEKW
# 28                         oMeIon      93          hi
# 29                    darkbunny11      93       First
# ...                           ...     ...         ...
# 170554           MadamPandamonium   36363
# 170555                asap_cvmpxs   36365
# 170556                 itsKiksuya   36367
# 170557                  Smoothyde   36367
# 170558                hi_im_ayuki   36373
# 170559                 UstaGevsek   36375
# 170560  gracwlolamuszebosieudusze   36375
# 170561                     Echosm   36387
# 170562                     mmated   36392
# 170563                    Golonk4   36394
# 170564                  mstfbglyn   36397
# 170565           MadamPandamonium   36399
# 170566                   gege_101   36401
# 170567                    Sganian   36403
# 170568                  MartinFNT   36404
# 170569                     kkbyt9   36406
# 170570                   shenlagh   36407
# 170571                   badwaduu   36410
# 170572                  escoesco_   36412
# 170573                    Borieko   36417
# 170574                    HAXUS01   36427
# 170575           MadamPandamonium   36430
# 170576                 Yasuoazaki   36432
# 170577                    bpa1708   36432
# 170578                  davidpg99   36448
# 170579                    SKYGA01   36449
# 170580                 LarcenyCat   36454
# 170581            theundertaker21   36454
# 170582              joaoesteves10   36455
# 170583                 cchasechen   36456
#
#                          username
# 0                       238samixd
# 1                     alexbomba25
# 2                      reformance
# 3                       j0hn_w3st
# 4                    mohamedmak11
# 5                          mossez
# 6                   thegameframer
# 7                         lemonzw
# 8                          nomacu
# 9                         saschzi
# 10                     powervital
# 11                        gibbxyz
# 12                      serjjarch
# 13                  karcsi1111222
# 14                      son_abdul
# 15                      dunforth1
# 16                  roseecho25345
# 17                 bangbangitybam
# 18                       schwille
# 19                      yeesharoo
# 20                       patatsta
# 21               autofill_collins
# 22                       tamare31
# 23                      j0hn_w3st
# 24                     harakaishu
# 25                       cremuwka
# 26                        lemonzw
# 27                    caniellafae
# 28                         omeion
# 29                    darkbunny11
# ...                           ...
# 170554           madampandamonium
# 170555                asap_cvmpxs
# 170556                 itskiksuya
# 170557                  smoothyde
# 170558                hi_im_ayuki
# 170559                 ustagevsek
# 170560  gracwlolamuszebosieudusze
# 170561                     echosm
# 170562                     mmated
# 170563                    golonk4
# 170564                  mstfbglyn
# 170565           madampandamonium
# 170566                   gege_101
# 170567                    sganian
# 170568                  martinfnt
# 170569                     kkbyt9
# 170570                   shenlagh
# 170571                   badwaduu
# 170572                  escoesco_
# 170573                    borieko
# 170574                    haxus01
# 170575           madampandamonium
# 170576                 yasuoazaki
# 170577                    bpa1708
# 170578                  davidpg99
# 170579                    skyga01
# 170580                 larcenycat
# 170581            theundertaker21
# 170582              joaoesteves10
# 170583                 cchasechen
#
# [170584 rows x 9 columns]

# %%
df = pd.DataFrame(data, columns= ['body', 'name','is_subscriber','offset'])

# %%
import pandas as pd

# %%
df.head()
# Out:
#                          body          name  is_subscriber  offset
# 0                 MorphinTime     238SAMIxD          False       8
# 1             HeyGuys HeyGuys   alexbomba25          False      27
# 2  PogChamp PogChamp PogChamp    Reformance          False      27
# 3                   caedChair     j0hn_w3st          False      40
# 4             HeyGuys HeyGuys  mohamedmak11          False      40

# %%
df.to_csv (r'C:\Users\Aleksandra\Desktop\export_dataframe.csv', index = False, header=True)

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
def sentiment_analyzer_scores(sentence):
    score = analyser.polarity_scores(sentence)
    print("{:-<40} {}".format(sentence, str(score)))

# %%
sentiment_analyzer_scores("The phone is super cool.")
# Out:
# The phone is super cool.---------------- {'neg': 0.0, 'neu': 0.326, 'pos': 0.674, 'compound': 0.7351}

# %%
sentiment_analyzer_scores("The phone is super COOL!")
# Out:
# The phone is super COOL!---------------- {'neg': 0.0, 'neu': 0.293, 'pos': 0.707, 'compound': 0.8034}

# %%
print(sentiment_analyzer_scores("Today SUX!"))
# Out:
# Today SUX!------------------------------ {'neg': 0.779, 'neu': 0.221, 'pos': 0.0, 'compound': -0.5461}
# None

# %%
sentiment_analyzer_scores("Today SUX!")
# Out:
# Today SUX!------------------------------ {'neg': 0.779, 'neu': 0.221, 'pos': 0.0, 'compound': -0.5461}

# %%
sentiment_analyzer_scores("Make sure you :) or :D today!")
# Out:
# Make sure you :) or :D today!----------- {'neg': 0.0, 'neu': 0.294, 'pos': 0.706, 'compound': 0.8633}

# %%
sentiment_analyzer_scores("Make sure you :) or :D today!"))

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# C:\Users\Aleksandra\.conda\envs\nlp_course\lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
df['scores'] = df['body'].apply(lambda Description: analyser.polarity_scores(Description))
df
# Out:
#                                                      body  \
# 0                                             MorphinTime
# 1                                         HeyGuys HeyGuys
# 2                              PogChamp PogChamp PogChamp
# 3                                               caedChair
# 4                                         HeyGuys HeyGuys
# 5                                                 HeyGuys
# 6                                         HeyGuys HeyGuys
# 7                                               SeemsGood
# 8                 SeemsGood SeemsGood SeemsGood SeemsGood
# 9                                                 HeyGuys
# 10                                            MorphinTime
# 11                                               PogChamp
# 12                                                HeyGuys
# 13                                                WutFace
# 14                                        ResidentSleeper
# 15                        HeyGuys HeyGuys HeyGuys HeyGuys
# 16                                            <3 <3 <3 <3
# 17                                              SeemsGood
# 18                                                HeyGuys
# 19                                              SeemsGood
# 20                                VoteYea VoteYea VoteYea
# 21                                        HeyGuys HeyGuys
# 22                                                WutFace
# 23                                              nisqyTeam
# 24                                    drututDog drututDog
# 25                                               <3 <3 <3
# 26                                                LUL LUL
# 27                                                   KEKW
# 28                                                     hi
# 29                                                  First
# ...                                                   ...
# 170554                                             MaxLOL
# 170555                buerinMusic buerinMusic buerinMusic
# 170556                                         PokPikachu
# 170557                                  <3 <3 <3 <3 <3 <3
# 170558                                   <3 BibleThump <3
# 170559                               <3 <3 <3 <3 <3 <3 <3
# 170560                                        Kappa Kappa
# 170561                                          maholi2Xd
# 170562                                                 <3
# 170563                            PowerUpL DxCat PowerUpR
# 170564                PogChamp PogChamp PogChamp PogChamp
# 170565                         <3 <3 KappaRoss BloodTrail
# 170566                                                 <3
# 170567                                                 <3
# 170568                                         mave88Love
# 170569                                           <3 <3 <3
# 170570                              BibleThump BibleThump
# 170571                <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3
# 170572                NotLikeThis NotLikeThis NotLikeThis
# 170573                PogChamp PogChamp PogChamp PogChamp
# 170574                                            FortOne
# 170575                           BibleThump BibleThump :D
# 170576  2020Celebrate 2020Celebrate 2020Celebrate 2020...
# 170577  HungryPaimon HungryPaimon HungryPaimon HungryP...
# 170578                                          EleGiggle
# 170579                                                 :)
# 170580                                        larcen2Wave
# 170581                                     <3 <3 <3 <3 <3
# 170582                                          ahnyfaPog
# 170583                         sinaOdin sinaOdin sinaOdin
#
#                              name  is_subscriber  offset  \
# 0                       238SAMIxD          False       8
# 1                     alexbomba25          False      27
# 2                      Reformance          False      27
# 3                       j0hn_w3st          False      40
# 4                    mohamedmak11          False      40
# 5                          Mossez          False      46
# 6                   TheGameFramer          False      47
# 7                         lemonzw          False      50
# 8                          nomacu          False      52
# 9                         SaschZi          False      53
# 10                     powervital          False      53
# 11                        Gibbxyz          False      54
# 12                      serjjarch          False      57
# 13                  karcsi1111222          False      58
# 14                      son_abdul          False      58
# 15                      Dunforth1          False      63
# 16                  roseecho25345          False      64
# 17                 BangBangityBam          False      65
# 18                       Schwille          False      65
# 19                      yeesharoo          False      66
# 20                       Patatsta          False      67
# 21               autofill_collins          False      67
# 22                       Tamare31          False      68
# 23                      j0hn_w3st          False      71
# 24                     harakaishu          False      73
# 25                       cremuwka          False      89
# 26                        lemonzw          False      90
# 27                    CaniellaFae          False      92
# 28                         oMeIon          False      93
# 29                    darkbunny11          False      93
# ...                           ...            ...     ...
# 170554           MadamPandamonium          False   36363
# 170555                asap_cvmpxs          False   36365
# 170556                 itsKiksuya          False   36367
# 170557                  Smoothyde          False   36367
# 170558                hi_im_ayuki          False   36373
# 170559                 UstaGevsek          False   36375
# 170560  gracwlolamuszebosieudusze          False   36375
# 170561                     Echosm          False   36387
# 170562                     mmated          False   36392
# 170563                    Golonk4          False   36394
# 170564                  mstfbglyn          False   36397
# 170565           MadamPandamonium          False   36399
# 170566                   gege_101          False   36401
# 170567                    Sganian          False   36403
# 170568                  MartinFNT          False   36404
# 170569                     kkbyt9          False   36406
# 170570                   shenlagh          False   36407
# 170571                   badwaduu          False   36410
# 170572                  escoesco_          False   36412
# 170573                    Borieko          False   36417
# 170574                    HAXUS01          False   36427
# 170575           MadamPandamonium          False   36430
# 170576                 Yasuoazaki          False   36432
# 170577                    bpa1708          False   36432
# 170578                  davidpg99          False   36448
# 170579                    SKYGA01          False   36449
# 170580                 LarcenyCat          False   36454
# 170581            theundertaker21          False   36454
# 170582              joaoesteves10          False   36455
# 170583                 cchasechen          False   36456
#
#                                                    scores
# 0       {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1       {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2       {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3       {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4       {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 5       {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 6       {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 7       {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 8       {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 9       {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 10      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 11      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 12      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 13      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 14      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 15      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 16      {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...
# 17      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 18      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 19      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 20      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 21      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 22      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 23      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 24      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 25      {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...
# 26      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 27      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 28      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 29      {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# ...                                                   ...
# 170554  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 170555  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 170556  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 170557  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...
# 170558  {'neg': 0.0, 'neu': 0.147, 'pos': 0.853, 'comp...
# 170559  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...
# 170560  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 170561  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 170562  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...
# 170563  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 170564  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 170565  {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'comp...
# 170566  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...
# 170567  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...
# 170568  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 170569  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...
# 170570  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 170571  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...
# 170572  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 170573  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 170574  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 170575  {'neg': 0.0, 'neu': 0.332, 'pos': 0.668, 'comp...
# 170576  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 170577  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 170578  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 170579  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...
# 170580  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 170581  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...
# 170582  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 170583  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#
# [170584 rows x 5 columns]
