# %%
import pandas as pd
import nltk

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer


analyzer = SentimentIntensityAnalyzer()
sentence = "The food was great!" 
vs = analyzer.polarity_scores(sentence)

# %%
print("{:-<65} {}".format(sentence, str(vs)))
# Out:
# The food was great!---------------------------------------------- {'neg': 0.0, 'neu': 0.406, 'pos': 0.594, 'compound': 0.6588}

# %%
pwd
# Out:
# 'C:\\Users\\Gustavo Chinchayan\\Documents\\Python\\DLD'

# %%
greek_ds = pd.read_csv('ChatLogs/chatgreekgodx091421Clean.csv')

# %%
greek_ds.head()
# Out:
#                   Date     Channel         Username              Message  \
# 0  2021-09-14 17:51:09  greekgodx         mustfax19               Pepega
# 1  2021-09-14 17:51:09  greekgodx          bangkeys   Irl stream snipers
# 2  2021-09-14 17:51:09  greekgodx   exiledxinsanity  v tec kicked in Pog
# 3  2021-09-14 17:51:10  greekgodx           no_much         pepeMeltdown
# 4  2021-09-14 17:51:10  greekgodx        alundz0114    SMOrc SMOrc SMOrc
#
#    Tag_owner clean_message_duplicates
# 0          0                   Pepega
# 1          0       Irl stream snipers
# 2          0      v tec kicked in Pog
# 3          0             pepeMeltdown
# 4          0                    SMOrc

# %%
new_emotes = {
    'OMEGALUL': 0,
    'LULW': 0,
    'monkaW': -3.0,
    'WAYTOODANK': 0,
    'EZ': 2.0,
    'Clap' : 3.0,
    'LUL' : 0,
    'BOOBA' : 1.0,
    'Pepega' : -3.0,
    'FeelsGoodMan' : 3.0,
    'WutFace' : -3.0,
    'Sadge' : -4.0,
    'Kreygasm' : 3.0,
    'Kappa' : 0,
    'peepoSad' : -4.0,
    'PogU' : 4.0,
    'TRUEING' : 0,
    'monkaS' : -2
}

# %%
SIA = SentimentIntensityAnalyzer()

SIA.lexicon.update(new_emotes)

# %%
greek_ds['scores'] = greek_ds['clean_message_duplicates'].apply(lambda clean_message_duplicates:analyzer.polarity_scores(clean_message_duplicates))

# %%
greek_ds.head(25)
# Out:
#                    Date     Channel          Username  \
# 0   2021-09-14 17:51:09  greekgodx          mustfax19
# 1   2021-09-14 17:51:09  greekgodx           bangkeys
# 2   2021-09-14 17:51:09  greekgodx    exiledxinsanity
# 3   2021-09-14 17:51:10  greekgodx            no_much
# 4   2021-09-14 17:51:10  greekgodx         alundz0114
# 5   2021-09-14 17:51:10  greekgodx              5zipp
# 6   2021-09-14 17:51:10  greekgodx           mrdude90
# 7   2021-09-14 17:51:10  greekgodx           bilaal44
# 8   2021-09-14 17:51:10  greekgodx             leeqox
# 9   2021-09-14 17:51:10  greekgodx         alundz0114
# 10  2021-09-14 17:51:10  greekgodx         patbashink
# 11  2021-09-14 17:51:10  greekgodx            adamev1
# 12  2021-09-14 17:51:10  greekgodx           intfanis
# 13  2021-09-14 17:51:11  greekgodx           olmas973
# 14  2021-09-14 17:51:11  greekgodx             proxe0
# 15  2021-09-14 17:51:11  greekgodx            paxt___
# ...

# %%
df['compound'] = df['scores'].apply(lambda d:d['compound'])
